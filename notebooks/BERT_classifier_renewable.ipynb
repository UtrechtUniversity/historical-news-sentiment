# %%
from pathlib import Path
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# %%
def confusion_classification_report(prediction_fp, method_title):
    print("\n" + "=" * len(method_title))
    print(method_title.upper())
    print("=" * len(method_title))
    
    df = pd.read_csv(prediction_fp)
    y_true = df['true_labels']
    y_pred = df['predictions']
    
    cm = confusion_matrix(y_true, y_pred)
    print("\nConfusion Matrix:\n", cm)
    
    report = classification_report(y_true, y_pred, digits=3)
    print("\nClassification Report:\n", report)

# %%
prediction_fp="../../output/renewable/output_renewable/predict/bertje_class2/predictions.csv"
method_title="BERTje Sentiment Model: Confusion Matrix and Classification Report (Binary Classification)"
confusion_classification_report(prediction_fp, method_title)

prediction_fp="../../output/renewable/output_renewable/predict/gysbert_class2/predictions.csv"
method_title="GysBERT Sentiment Model: Confusion Matrix and Classification Report (Binary Classification)"
confusion_classification_report(prediction_fp, method_title)

prediction_fp="../../output/renewable/output_renewable/predict/robbert_class2/predictions.csv"
method_title="RobBERT Sentiment Model: Confusion Matrix and Classification Report (Binary Classification)"
confusion_classification_report(prediction_fp, method_title)
# Out:
# ==========================================================================================
# BERTJE SENTIMENT MODEL: CONFUSION MATRIX AND CLASSIFICATION REPORT (BINARY CLASSIFICATION)
# ==========================================================================================
#
# Confusion Matrix:
#  [[  0  87  17]
#  [  0 583  71]
#  [  0  68 604]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0      0.000     0.000     0.000       104
#            1      0.790     0.891     0.838       654
#            2      0.873     0.899     0.886       672
#
#     accuracy                          0.830      1430
#    macro avg      0.554     0.597     0.574      1430
# weighted avg      0.771     0.830     0.799      1430
#
#
# ===========================================================================================
# GYSBERT SENTIMENT MODEL: CONFUSION MATRIX AND CLASSIFICATION REPORT (BINARY CLASSIFICATION)
# ===========================================================================================
#
# Confusion Matrix:
#  [[100   1   3]
#  [384 259  11]
#  [190  59 423]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0      0.148     0.962     0.257       104
#            1      0.812     0.396     0.532       654
#            2      0.968     0.629     0.763       672
#
#     accuracy                          0.547      1430
#    macro avg      0.643     0.662     0.517      1430
# weighted avg      0.837     0.547     0.621      1430
#
#
# ===========================================================================================
# ROBBERT SENTIMENT MODEL: CONFUSION MATRIX AND CLASSIFICATION REPORT (BINARY CLASSIFICATION)
# ===========================================================================================
#
# Confusion Matrix:
#  [[ 56  36  12]
#  [ 28 592  34]
#  [ 11  27 634]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0      0.589     0.538     0.563       104
#            1      0.904     0.905     0.905       654
#            2      0.932     0.943     0.938       672
#
#     accuracy                          0.897      1430
#    macro avg      0.809     0.796     0.802      1430
# weighted avg      0.894     0.897     0.895      1430
# /Users/Zahed001/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/Zahed001/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/Zahed001/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
prediction_fp="../../output/renewable/output_renewable/predict/bertje_class3/predictions.csv"
method_title="BERTje Sentiment Model: Confusion Matrix and Classification Report (multiclass Classification)"
confusion_classification_report(prediction_fp, method_title)

prediction_fp="../../output/renewable/output_renewable/predict/gysbert_class3/predictions.csv"
method_title="GysBERT Sentiment Model: Confusion Matrix and Classification Report (multiclass Classification)"
confusion_classification_report(prediction_fp, method_title)

prediction_fp="../../output/renewable/output_renewable/predict/robbert_class3/predictions.csv"
method_title="RobBERT Sentiment Model: Confusion Matrix and Classification Report (multiclass Classification)"
confusion_classification_report(prediction_fp, method_title)
# Out:
# ==============================================================================================
# BERTJE SENTIMENT MODEL: CONFUSION MATRIX AND CLASSIFICATION REPORT (MULTICLASS CLASSIFICATION)
# ==============================================================================================
#
# Confusion Matrix:
#  [[ 75   0   4  25]
#  [ 98   0  30  25]
#  [186   0 267  48]
#  [ 23   0  12 637]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0      0.196     0.721     0.309       104
#            1      0.000     0.000     0.000       153
#            2      0.853     0.533     0.656       501
#            3      0.867     0.948     0.905       672
#
#     accuracy                          0.685      1430
#    macro avg      0.479     0.551     0.468      1430
# weighted avg      0.720     0.685     0.678      1430
#
#
# ===============================================================================================
# GYSBERT SENTIMENT MODEL: CONFUSION MATRIX AND CLASSIFICATION REPORT (MULTICLASS CLASSIFICATION)
# ===============================================================================================
#
# Confusion Matrix:
#  [[ 40  42   9  13]
#  [ 10  86  41  16]
#  [  9 106 350  36]
#  [  3  44  32 593]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0      0.645     0.385     0.482       104
#            1      0.309     0.562     0.399       153
#            2      0.810     0.699     0.750       501
#            3      0.901     0.882     0.892       672
#
#     accuracy                          0.748      1430
#    macro avg      0.666     0.632     0.631      1430
# weighted avg      0.787     0.748     0.760      1430
#
#
# ===============================================================================================
# ROBBERT SENTIMENT MODEL: CONFUSION MATRIX AND CLASSIFICATION REPORT (MULTICLASS CLASSIFICATION)
# ===============================================================================================
#
# Confusion Matrix:
#  [[  0   0   0 104]
#  [  0   0   0 153]
#  [  0   0   0 501]
#  [  0   0   0 672]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0      0.000     0.000     0.000       104
#            1      0.000     0.000     0.000       153
#            2      0.000     0.000     0.000       501
#            3      0.470     1.000     0.639       672
#
#     accuracy                          0.470      1430
#    macro avg      0.117     0.250     0.160      1430
# weighted avg      0.221     0.470     0.300      1430
# /Users/Zahed001/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/Zahed001/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/Zahed001/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/Zahed001/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/Zahed001/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/Zahed001/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
