# %%
from pathlib import Path
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# %%
def confusion_classification_report(prediction_fp, method_title):
    print("\n" + "=" * len(method_title))
    print(method_title.upper())
    print("=" * len(method_title))
    
    df = pd.read_csv(prediction_fp)
    y_true = df['true_labels']
    y_pred = df['predictions']
    
    cm = confusion_matrix(y_true, y_pred)
    print("\nConfusion Matrix:\n", cm)
    
    report = classification_report(y_true, y_pred, digits=3)
    print("\nClassification Report:\n", report)

# %%
prediction_fp="../../output/nuclear/predict/bertje_class2/predictions.csv"
method_title="BERTje Sentiment Model: Confusion Matrix and Classification Report (Binary Classification)"
confusion_classification_report(prediction_fp, method_title)

prediction_fp="../../output/nuclear/predict/gysbert_class2/predictions.csv"
method_title="GysBERT Sentiment Model: Confusion Matrix and Classification Report (Binary Classification)"
confusion_classification_report(prediction_fp, method_title)

prediction_fp="../../output/nuclear/predict/robbert_class2/predictions.csv"
method_title="RobBERT Sentiment Model: Confusion Matrix and Classification Report (Binary Classification)"
confusion_classification_report(prediction_fp, method_title)
# Out:
# ==========================================================================================
# BERTJE SENTIMENT MODEL: CONFUSION MATRIX AND CLASSIFICATION REPORT (BINARY CLASSIFICATION)
# ==========================================================================================
#
# Confusion Matrix:
#  [[478  69  45]
#  [197 571  39]
#  [ 58  44 499]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0      0.652     0.807     0.722       592
#            1      0.835     0.708     0.766       807
#            2      0.856     0.830     0.843       601
#
#     accuracy                          0.774      2000
#    macro avg      0.781     0.782     0.777      2000
# weighted avg      0.787     0.774     0.776      2000
#
#
# ===========================================================================================
# GYSBERT SENTIMENT MODEL: CONFUSION MATRIX AND CLASSIFICATION REPORT (BINARY CLASSIFICATION)
# ===========================================================================================
#
# Confusion Matrix:
#  [[350 170  72]
#  [111 625  71]
#  [ 40  54 507]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0      0.699     0.591     0.640       592
#            1      0.736     0.774     0.755       807
#            2      0.780     0.844     0.811       601
#
#     accuracy                          0.741      2000
#    macro avg      0.738     0.736     0.735      2000
# weighted avg      0.738     0.741     0.738      2000
#
#
# ===========================================================================================
# ROBBERT SENTIMENT MODEL: CONFUSION MATRIX AND CLASSIFICATION REPORT (BINARY CLASSIFICATION)
# ===========================================================================================
#
# Confusion Matrix:
#  [[406 148  38]
#  [101 653  53]
#  [ 59  62 480]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0      0.717     0.686     0.701       592
#            1      0.757     0.809     0.782       807
#            2      0.841     0.799     0.819       601
#
#     accuracy                          0.769      2000
#    macro avg      0.772     0.765     0.767      2000
# weighted avg      0.770     0.769     0.769      2000

# %%
prediction_fp="../../output/nuclear/predict/berje_class3/predictions.csv"
method_title="BERTje Sentiment Model: Confusion Matrix and Classification Report (multiclass Classification)"
confusion_classification_report(prediction_fp, method_title)

prediction_fp="../../output/nuclear/predict/gysbert_class3/predictions.csv"
method_title="GysBERT Sentiment Model: Confusion Matrix and Classification Report (multiclass Classification)"
confusion_classification_report(prediction_fp, method_title)

prediction_fp="../../output/nuclear/predict/robbert_class3/predictions.csv"
method_title="RobBERT Sentiment Model: Confusion Matrix and Classification Report (multiclass Classification)"
confusion_classification_report(prediction_fp, method_title)
# Out:
# ==============================================================================================
# BERTJE SENTIMENT MODEL: CONFUSION MATRIX AND CLASSIFICATION REPORT (MULTICLASS CLASSIFICATION)
# ==============================================================================================
#
# Confusion Matrix:
#  [[415  72  12  93]
#  [ 98 320  32  74]
#  [ 48  76 126  33]
#  [ 24  26   0 551]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0      0.709     0.701     0.705       592
#            1      0.648     0.611     0.629       524
#            2      0.741     0.445     0.556       283
#            3      0.734     0.917     0.815       601
#
#     accuracy                          0.706      2000
#    macro avg      0.708     0.668     0.676      2000
# weighted avg      0.705     0.706     0.697      2000
#
#
# ===============================================================================================
# GYSBERT SENTIMENT MODEL: CONFUSION MATRIX AND CLASSIFICATION REPORT (MULTICLASS CLASSIFICATION)
# ===============================================================================================
#
# Confusion Matrix:
#  [[378 102  58  54]
#  [ 62 317  98  47]
#  [ 22  50 193  18]
#  [ 49  40  12 500]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0      0.740     0.639     0.685       592
#            1      0.623     0.605     0.614       524
#            2      0.535     0.682     0.599       283
#            3      0.808     0.832     0.820       601
#
#     accuracy                          0.694      2000
#    macro avg      0.676     0.689     0.680      2000
# weighted avg      0.701     0.694     0.695      2000
#
#
# ===============================================================================================
# ROBBERT SENTIMENT MODEL: CONFUSION MATRIX AND CLASSIFICATION REPORT (MULTICLASS CLASSIFICATION)
# ===============================================================================================
#
# Confusion Matrix:
#  [[379 100  53  60]
#  [ 99 274 103  48]
#  [ 52  60 149  22]
#  [ 69  52  18 462]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0      0.633     0.640     0.636       592
#            1      0.564     0.523     0.543       524
#            2      0.461     0.527     0.492       283
#            3      0.780     0.769     0.775       601
#
#     accuracy                          0.632      2000
#    macro avg      0.610     0.615     0.611      2000
# weighted avg      0.635     0.632     0.633      2000
